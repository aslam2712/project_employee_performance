# %%
#First Requirement: Department wise analysis.

# %%
import pandas as pd
import numpy as np

# %%
file_path = "INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls"
data_1 = pd.read_excel(file_path)

# %%
data_1.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# ...

# %%
data_dep = data_1.groupby(data_1['EmpDepartment'])

# %%
data_dep.mean()
# Out:
#                               Age  DistanceFromHome  EmpEducationLevel  \
# EmpDepartment
# Data Science            38.000000          9.650000           2.750000
# Development             36.653740          8.789474           2.853186
# Finance                 36.387755         11.877551           3.061224
# Human Resources         38.425926          8.666667           3.000000
# Research & Development  37.475219          9.230321           2.874636
# Sales                   36.455764          9.160858           2.916890
#
#                         EmpEnvironmentSatisfaction  EmpHourlyRate  \
# EmpDepartment
# Data Science                              2.950000      62.250000
# Development                               2.709141      65.828255
# Finance                                   2.836735      66.693878
# Human Resources                           2.629630      65.703704
# Research & Development                    2.775510      67.023324
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
# %matplotlib inline

# %%
output = data_1.loc[:,['EmpDepartment','PerformanceRating']]

# %%
output_dep1 = output.groupby(output['EmpDepartment'])

# %%
output_dep1.mean()
# Out:
#                         PerformanceRating
# EmpDepartment
# Data Science                     3.050000
# Development                      3.085873
# Finance                          2.775510
# Human Resources                  2.925926
# Research & Development           2.921283
# Sales                            2.860590

# %%
# second requirement : Most Effective Parameters:

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb
import numpy as np

# %%
data1=data.iloc[:,1:] #Zero index column EmpNumber has no significance related to performance

# %%
data=pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + Gender + EducationBackground + MaritalStatus + EmpDepartment + EmpJobRole + BusinessTravelFrequency + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + NumCompaniesWorked + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + TrainingTimesLastYear + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager + Attrition', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     14.78
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           9.30e-92
# Time:                        21:09:48   Log-Likelihood:                -616.85
# No. Observations:                1200   AIC:                             1336.
# Df Residuals:                    1149   BIC:                             1595.
# Df Model:                          50
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %%
#We will eliminate the feature having the highest p value in each step untill all p values are less than significance value 0.05

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + Gender + EducationBackground + MaritalStatus + EmpDepartment + EmpJobRole + BusinessTravelFrequency + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + NumCompaniesWorked + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager + Attrition', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     15.10
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           2.38e-92
# Time:                        21:10:17   Log-Likelihood:                -616.85
# No. Observations:                1200   AIC:                             1334.
# Df Residuals:                    1150   BIC:                             1588.
# Df Model:                          49
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + Gender + EducationBackground + MaritalStatus + EmpDepartment + EmpJobRole + BusinessTravelFrequency + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager + Attrition', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     15.43
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           6.02e-93
# Time:                        21:10:30   Log-Likelihood:                -616.85
# No. Observations:                1200   AIC:                             1332.
# Df Residuals:                    1151   BIC:                             1581.
# Df Model:                          48
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + Gender + EducationBackground + MaritalStatus + EmpDepartment + BusinessTravelFrequency + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager + Attrition', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.381
# Model:                            OLS   Adj. R-squared:                  0.364
# Method:                 Least Squares   F-statistic:                     21.77
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           1.68e-98
# Time:                        21:10:43   Log-Likelihood:                -626.86
# No. Observations:                1200   AIC:                             1322.
# Df Residuals:                    1166   BIC:                             1495.
# Df Model:                          33
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + Gender + EducationBackground + EmpDepartment + BusinessTravelFrequency + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager + Attrition', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.380
# Model:                            OLS   Adj. R-squared:                  0.364
# Method:                 Least Squares   F-statistic:                     23.14
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           1.45e-99
# Time:                        21:10:54   Log-Likelihood:                -627.60
# No. Observations:                1200   AIC:                             1319.
# Df Residuals:                    1168   BIC:                             1482.
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + Gender + EducationBackground + EmpDepartment + BusinessTravelFrequency + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.380
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     23.93
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):          3.00e-100
# Time:                        21:11:08   Log-Likelihood:                -627.62
# No. Observations:                1200   AIC:                             1317.
# Df Residuals:                    1169   BIC:                             1475.
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + EducationBackground + EmpDepartment + BusinessTravelFrequency + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.380
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     24.77
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):          6.31e-101
# Time:                        21:11:21   Log-Likelihood:                -627.68
# No. Observations:                1200   AIC:                             1315.
# Df Residuals:                    1170   BIC:                             1468.
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + EducationBackground + EmpDepartment + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.379
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     26.55
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):          5.43e-102
# Time:                        21:11:33   Log-Likelihood:                -628.57
# No. Observations:                1200   AIC:                             1313.
# Df Residuals:                    1172   BIC:                             1456.
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + EducationBackground + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.346
# Model:                            OLS   Adj. R-squared:                  0.334
# Method:                 Least Squares   F-statistic:                     28.33
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           9.08e-93
# Time:                        21:11:46   Log-Likelihood:                -659.88
# No. Observations:                1200   AIC:                             1366.
# Df Residuals:                    1177   BIC:                             1483.
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + EmpRelationshipSatisfaction + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     36.64
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           3.68e-96
# Time:                        21:11:58   Log-Likelihood:                -660.93
# No. Observations:                1200   AIC:                             1358.
# Df Residuals:                    1182   BIC:                             1449.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobInvolvement + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     38.96
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           5.82e-97
# Time:                        21:12:08   Log-Likelihood:                -660.93
# No. Observations:                1200   AIC:                             1356.
# Df Residuals:                    1183   BIC:                             1442.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobLevel + EmpJobSatisfaction + OverTime + EmpLastSalaryHikePercent + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion + YearsWithCurrManager', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     41.59
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           9.18e-98
# Time:                        21:12:19   Log-Likelihood:                -660.97
# No. Observations:                1200   AIC:                             1354.
# Df Residuals:                    1184   BIC:                             1435.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ Age + DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobLevel + OverTime + EmpLastSalaryHikePercent + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     48.01
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):           2.43e-99
# Time:                        21:12:30   Log-Likelihood:                -661.22
# No. Observations:                1200   AIC:                             1350.
# Df Residuals:                    1186   BIC:                             1422.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobLevel + OverTime + EmpLastSalaryHikePercent + TotalWorkExperienceInYears + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.344
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     51.95
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):          4.92e-100
# Time:                        21:12:42   Log-Likelihood:                -661.63
# No. Observations:                1200   AIC:                             1349.
# Df Residuals:                    1187   BIC:                             1415.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + EmpJobLevel + OverTime + EmpLastSalaryHikePercent + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.344
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     56.64
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):          8.36e-101
# Time:                        21:12:52   Log-Likelihood:                -661.91
# No. Observations:                1200   AIC:                             1348.
# Df Residuals:                    1188   BIC:                             1409.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpHourlyRate + OverTime + EmpLastSalaryHikePercent + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.344
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     62.25
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):          1.46e-101
# Time:                        21:13:02   Log-Likelihood:                -662.27
# No. Observations:                1200   AIC:                             1347.
# Df Residuals:                    1189   BIC:                             1403.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + OverTime + EmpLastSalaryHikePercent + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.343
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     69.08
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):          2.59e-102
# Time:                        21:13:11   Log-Likelihood:                -662.69
# No. Observations:                1200   AIC:                             1345.
# Df Residuals:                    1190   BIC:                             1396.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.formula.api as sm
mod = sm.ols(formula='PerformanceRating ~ DistanceFromHome + EmpEducationLevel + EmpEnvironmentSatisfaction + EmpLastSalaryHikePercent + EmpWorkLifeBalance + ExperienceYearsAtThisCompany + ExperienceYearsInCurrentRole + YearsSinceLastPromotion', data=data1)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      PerformanceRating   R-squared:                       0.342
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     77.54
# Date:                Sat, 31 Mar 2018   Prob (F-statistic):          5.32e-103
# Time:                        21:13:21   Log-Likelihood:                -663.33
# No. Observations:                1200   AIC:                             1345.
# Df Residuals:                    1191   BIC:                             1390.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
#From the above results all the p values are less than than 0.05(p<0.05).
#Therefore the above features influences the performance most

#From the above results top 3 important factors effecting the performance includes the following
#1.EmpLastSalaryHikePercent (has p value 0.000 and std err is very small) 
#2.ExperienceYearsInCurrentRole 
#3.YearsSinceLastPromotion (t values for 2 is smaller than 3 even though std err is sam so ExperienceYearsInCurrentRole is second factor)

# %%
#3rd requirement : use machine learning algorithm to that can help in hiring new employees:

# %%
from random import seed
from random import randrange

# %%
from csv import reader
from math import sqrt

# %%
seed (1)
filename = 'INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls'

# %%
dataset = pd.read_excel(filename)

# %%
dataset.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = dataset.drop("PerformanceRating", axis = 1)
X = pd.get_dummies(X)
X.head()
# Out:
#    Age  DistanceFromHome  EmpEducationLevel  EmpEnvironmentSatisfaction  \
# 0   32                10                  3                           4
# 1   47                14                  4                           4
# 2   40                 5                  4                           4
# 3   41                10                  4                           2
# 4   60                16                  4                           1
#
#    EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  EmpJobSatisfaction  \
# 0             55                  3            2                   4
# 1             42                  3            2                   1
# 2             48                  2            3                   1
# 3             73                  2            5                   4
# 4             84                  3            2                   1
#
#    NumCompaniesWorked  EmpLastSalaryHikePercent      ...        \
# ...

# %%
y = dataset.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators= 101, random_state=33)

# %%
# Train the model on training data

# %%
rf.fit(X_train,y_train)
#fit training set
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=101, n_jobs=1,
#            oob_score=False, random_state=33, verbose=0, warm_start=False)

# %%
y_test = y_test

# %%
predictions =rf.predict(X_test)
errors = abs(predictions - y_test)

# %%
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 0.1 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)

# %%
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 96.59 %.

# %%
#requirement 4 : Analysis

# %%
 				Reqiuerment 1 : 
			Department wise performances:


File saved as project_employee_performance\src\data processing\data_processing_department_wise_analysis

- Imported pandas and numpy.
- Loaded data
- Arranged data by Using Group by and Gruoped data on Basis on EmpDepartment.
data_dep = data_1.groupby(data_1['EmpDepartment'])

-calculated  mean of grouped data.
- this gives performance Rating based on EmpDepartment

- Also plotted graph using Tableau to visualize data . scrren shoot of Tableau is attached in 
project_employee_performance\src\visualization

				Final Result :
Development : 3.05
Data Science : 3.05
Human Resource : 2.92



				Requirement 2 : 
		Top 3 Important Factors effecting employee performance
-File saved as Most_effective_parameter in location
project_employee_performance\src\data processing
-Loaded Numpy , pandas , rcParams, ststsmodel.formula.api
-Generated summary considering all Parameters :
- observed p-value of all the features and removed feature with max p- value
-continued to remove parameters untill all features were left with p-value less then .05
        
		Final result: Most effective parameters are:
1.EmpLastSalaryHikePercent (has p value 0.000 and std err is very small) 
2.ExperienceYearsInCurrentRole 
3.YearsSinceLastPromotion 



				Requirement 3
A trained model which can predict the employee performance based on factors as inputs. 
This will be used to hire employees
 
-Imported Numpy, panads , seed, randrange, sqrt
- Loaded data.
-Imported train_test_split
- Loaded all features in X and performance (last column) in y.
- splitted data in training data and test data using Train_test_split
- used RandomForestClassifier to Train Data.
-Fitted X_train and y_Train to train model.
- calculated predictions with reference on X_test
- calculated error , by substracting pridiction from actual y_test.
- calculated mean absolute percentage error.
- calculated accuracy.
Its out to be 84.07%


			Requirement 4:
Recommendations to improve the employee performance based on insights from analysis.

- Based on all out put we can suggest following Point:

- people on development have best performance .
- Salary hike is most important feature in performance that should be given more waightage.
- Employee shall be hired on basis for specific Role with relevant experince in that role .
- promotions shall be given on regualr Interval that keeps Employee motivated.
- we can use RandomForestClassifier model and put all features as input while hiring new employess and predicted 
performance shall be as accuarte as 96%.
